# %% [markdown]
# # Ch-1 Measure Theory
# This is the review for Measure Theory from the Reference Book.

# %% [markdown]
# ## Classes of Sets
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## Lambda & pi Systems
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Example sets
# Different types of set systems used in **measure theory**, including:
# 1. Algebra
# 2. Sigma Algebra
# 3. Dynkin Systems
# 4. Semirings
# 5. Rings
# 6. Sigma Rings
#
#
# ***Countable union***: is a union of countably infinite sets (i.e infinite no of sets, indexed by natural numbers). It involves Union of Finite sets and Union of infinite sets, given that sets are indexed by natural Numbers.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-6.png](attachment:image-6.png)
#
#
# #### Examples
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Relationship b/w Algebra & a Ring
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **liminf** (limit inferior) & **limsup** (limit superior)
#
# ### **liminf**
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
#
# ### **limsup**
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# <br>
# <br>
# <br>
# liminf & limsup can be represented using:
#
# 1. **Set Notations**
#
# ![image-5.png](attachment:image-5.png)
#
# 2. **Functional Notations**
#
# ![image-6.png](attachment:image-6.png)
#
# 3. **Indicator Function Notation**
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ### Generated sigma Algebra
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Topological Space (only contains open sets)
#
# besides open sets, it also contains the complements of **Closed Sets** (which again are open)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
